# %%
# coding: utf-8
# pylint: disable = invalid-name, C0111
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

path = "c:/Users/Jiwan/Desktop/Hackathon/"
df = pd.read_csv(path+'nam.csv')

df_train, df_test = train_test_split(df, test_size=0.1, random_state=777)

y_train = df_train.iloc[:,2]
y_test = df_test.iloc[:,2]
X_train = df_train.iloc[:,3:]
X_test = df_test.iloc[:,3:]

# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=2000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)

gbm.save_model('model_nam.txt')

y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# eval
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# [1]	valid_0's l2: 5.12518e+07	valid_0's l1: 5808.45
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's l2: 5.05704e+07	valid_0's l1: 5766.78
# [3]	valid_0's l2: 4.96941e+07	valid_0's l1: 5695.82
# [4]	valid_0's l2: 4.93444e+07	valid_0's l1: 5670.82
# [5]	valid_0's l2: 4.85138e+07	valid_0's l1: 5600.16
# [6]	valid_0's l2: 4.81907e+07	valid_0's l1: 5575.16
# [7]	valid_0's l2: 4.737e+07	valid_0's l1: 5508.9
# [8]	valid_0's l2: 4.65687e+07	valid_0's l1: 5448.35
# [9]	valid_0's l2: 4.57883e+07	valid_0's l1: 5388.1
# [10]	valid_0's l2: 4.50285e+07	valid_0's l1: 5332.58
# [11]	valid_0's l2: 4.42405e+07	valid_0's l1: 5274.92
# [12]	valid_0's l2: 4.34726e+07	valid_0's l1: 5217.44
# [13]	valid_0's l2: 4.27243e+07	valid_0's l1: 5163.08
# [14]	valid_0's l2: 4.19951e+07	valid_0's l1: 5114.26
# [15]	valid_0's l2: 4.1659e+07	valid_0's l1: 5089.25
# [16]	valid_0's l2: 4.10133e+07	valid_0's l1: 5048.56
# [17]	valid_0's l2: 4.03856e+07	valid_0's l1: 5007.82
# [18]	valid_0's l2: 4.00174e+07	valid_0's l1: 4985.71
# [19]	valid_0's l2: 3.94346e+07	valid_0's l1: 4941.32
# [20]	valid_0's l2: 3.88516e+07	valid_0's l1: 4907.13
# [21]	valid_0's l2: 3.827e+07	valid_0's l1: 4881
# [22]	valid_0's l2: 3.78065e+07	valid_0's l1: 4844.24
# [23]	valid_0's l2: 3.72997e+07	valid_0's l1: 4814.66
# [24]	valid_0's l2: 3.70522e+07	valid_0's l1: 4793.61
# [25]	valid_0's l2: 3.66293e+07	valid_0's l1: 4774.74
# [26]	valid_0's l2: 3.61121e+07	valid_0's l1: 4747.75
# [27]	valid_0's l2: 3.57399e+07	valid_0's l1: 4723.23
# [28]	valid_0's l2: 3.52501e+07	valid_0's l1: 4702.1
# [29]	valid_0's l2: 3.50906e+07	valid_0's l1: 4692.83
# [30]	valid_0's l2: 3.46197e+07	valid_0's l1: 4670.64
# [31]	valid_0's l2: 3.42489e+07	valid_0's l1: 4651.26
# [32]	valid_0's l2: 3.39655e+07	valid_0's l1: 4638.15
# [33]	valid_0's l2: 3.36202e+07	valid_0's l1: 4618.79
# [34]	valid_0's l2: 3.33677e+07	valid_0's l1: 4605.61
# [35]	valid_0's l2: 3.32289e+07	valid_0's l1: 4594.66
# [36]	valid_0's l2: 3.2804e+07	valid_0's l1: 4569.47
# [37]	valid_0's l2: 3.25255e+07	valid_0's l1: 4555.94
# [38]	valid_0's l2: 3.21271e+07	valid_0's l1: 4535.34
# [39]	valid_0's l2: 3.20363e+07	valid_0's l1: 4520.81
# [40]	valid_0's l2: 3.16574e+07	valid_0's l1: 4499.81
# [41]	valid_0's l2: 3.13391e+07	valid_0's l1: 4483.04
# [42]	valid_0's l2: 3.12462e+07	valid_0's l1: 4460.97
# [43]	valid_0's l2: 3.09698e+07	valid_0's l1: 4447.64
# [44]	valid_0's l2: 3.05687e+07	valid_0's l1: 4404.67
# [45]	valid_0's l2: 3.02797e+07	valid_0's l1: 4395.05
# [46]	valid_0's l2: 2.99436e+07	valid_0's l1: 4395.98
# [47]	valid_0's l2: 2.93686e+07	valid_0's l1: 4369.18
# [48]	valid_0's l2: 2.90564e+07	valid_0's l1: 4369.46
# [49]	valid_0's l2: 2.85323e+07	valid_0's l1: 4334.22
# [50]	valid_0's l2: 2.78433e+07	valid_0's l1: 4286.43
# [51]	valid_0's l2: 2.78908e+07	valid_0's l1: 4295.62
# [52]	valid_0's l2: 2.75815e+07	valid_0's l1: 4275.79
# [53]	valid_0's l2: 2.72834e+07	valid_0's l1: 4256.13
# [54]	valid_0's l2: 2.70486e+07	valid_0's l1: 4246.13
# [55]	valid_0's l2: 2.68412e+07	valid_0's l1: 4230.76
# [56]	valid_0's l2: 2.68436e+07	valid_0's l1: 4242.22
# [57]	valid_0's l2: 2.68607e+07	valid_0's l1: 4260.7
# [58]	valid_0's l2: 2.68918e+07	valid_0's l1: 4278.89
# [59]	valid_0's l2: 2.67987e+07	valid_0's l1: 4270.68
# [60]	valid_0's l2: 2.67488e+07	valid_0's l1: 4272.18
# Early stopping, best iteration is:
# [55]	valid_0's l2: 2.68412e+07	valid_0's l1: 4230.76
# The rmse of prediction is: 5180.85199838

# %%
pd.DataFrame(gbm.predict(df.iloc[:,3:], num_iteration=gbm.best_iteration)).describe()
# Out:
#                   0
# count    240.000000
# mean   29102.714502
# std     4031.353377
# min    22651.087172
# 25%    23801.383766
# 50%    30866.700842
# 75%    32208.995991
# max    33651.087172
