# %%
# coding: utf-8
# pylint: disable = invalid-name, C0111
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

path = "c:/Users/Jiwan/Desktop/Hackathon/"
df = pd.read_csv(path+'lotte.csv')

df_train, df_test = train_test_split(df, test_size=0.1, random_state=777)

y_train = df_train.iloc[:,2]
y_test = df_test.iloc[:,2]
X_train = df_train.iloc[:,3:]
X_test = df_test.iloc[:,3:]

# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=2000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)

gbm.save_model('model_lotte.txt')

y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# eval
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# [1]	valid_0's l1: 7758.86	valid_0's l2: 7.80271e+07
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's l1: 7702.44	valid_0's l2: 7.69499e+07
# [3]	valid_0's l1: 7648.24	valid_0's l2: 7.59041e+07
# [4]	valid_0's l1: 7594.67	valid_0's l2: 7.48889e+07
# [5]	valid_0's l1: 7541.7	valid_0's l2: 7.39032e+07
# [6]	valid_0's l1: 7491.7	valid_0's l2: 7.33002e+07
# [7]	valid_0's l1: 7436.1	valid_0's l2: 7.2289e+07
# [8]	valid_0's l1: 7369.43	valid_0's l2: 7.1246e+07
# [9]	valid_0's l1: 7311.1	valid_0's l2: 7.03985e+07
# [10]	valid_0's l1: 7252.77	valid_0's l2: 6.95701e+07
# [11]	valid_0's l1: 7177.77	valid_0's l2: 6.84273e+07
# [12]	valid_0's l1: 7102.77	valid_0's l2: 6.73045e+07
# [13]	valid_0's l1: 7032.35	valid_0's l2: 6.6203e+07
# [14]	valid_0's l1: 6965.96	valid_0's l2: 6.51252e+07
# [15]	valid_0's l1: 6921.2	valid_0's l2: 6.45618e+07
# [16]	valid_0's l1: 6864.43	valid_0's l2: 6.36661e+07
# [17]	valid_0's l1: 6807.58	valid_0's l2: 6.27845e+07
# [18]	valid_0's l1: 6761.37	valid_0's l2: 6.21025e+07
# [19]	valid_0's l1: 6708.73	valid_0's l2: 6.12478e+07
# [20]	valid_0's l1: 6648.88	valid_0's l2: 6.03609e+07
# [21]	valid_0's l1: 6583.85	valid_0's l2: 5.9421e+07
# [22]	valid_0's l1: 6553.1	valid_0's l2: 5.90893e+07
# [23]	valid_0's l1: 6498.55	valid_0's l2: 5.82091e+07
# [24]	valid_0's l1: 6475.19	valid_0's l2: 5.79317e+07
# [25]	valid_0's l1: 6429.56	valid_0's l2: 5.74106e+07
# [26]	valid_0's l1: 6379.56	valid_0's l2: 5.67955e+07
# [65]	valid_0's l1: 4955.34	valid_0's l2: 4.05844e+07
# [66]	valid_0's l1: 4928.37	valid_0's l2: 4.0051e+07
# [67]	valid_0's l1: 4916.41	valid_0's l2: 3.99006e+07
# [68]	valid_0's l1: 4858.08	valid_0's l2: 3.91238e+07
# [69]	valid_0's l1: 4838.22	valid_0's l2: 3.91356e+07
# [70]	valid_0's l1: 4793.57	valid_0's l2: 3.84364e+07
# [71]	valid_0's l1: 4769.01	valid_0's l2: 3.81396e+07
# [72]	valid_0's l1: 4752.34	valid_0's l2: 3.78024e+07
# [73]	valid_0's l1: 4721.21	valid_0's l2: 3.76003e+07
# [74]	valid_0's l1: 4711.62	valid_0's l2: 3.72646e+07
# [75]	valid_0's l1: 4694.95	valid_0's l2: 3.69504e+07
# [76]	valid_0's l1: 4679.38	valid_0's l2: 3.69299e+07
# [77]	valid_0's l1: 4665.71	valid_0's l2: 3.67981e+07
# [78]	valid_0's l1: 4652.1	valid_0's l2: 3.66818e+07
# [79]	valid_0's l1: 4633.96	valid_0's l2: 3.66931e+07
# [80]	valid_0's l1: 4622.39	valid_0's l2: 3.65867e+07
# [81]	valid_0's l1: 4608.1	valid_0's l2: 3.66396e+07
# [82]	valid_0's l1: 4608	valid_0's l2: 3.65263e+07
# [83]	valid_0's l1: 4607.3	valid_0's l2: 3.6425e+07
# [84]	valid_0's l1: 4606.22	valid_0's l2: 3.63395e+07
# [85]	valid_0's l1: 4590.21	valid_0's l2: 3.61179e+07
# [86]	valid_0's l1: 4581.4	valid_0's l2: 3.61467e+07
# [87]	valid_0's l1: 4568.67	valid_0's l2: 3.6151e+07
# [88]	valid_0's l1: 4548.11	valid_0's l2: 3.59429e+07
# [89]	valid_0's l1: 4550	valid_0's l2: 3.59951e+07
# [90]	valid_0's l1: 4558.42	valid_0's l2: 3.6063e+07
# [91]	valid_0's l1: 4536.39	valid_0's l2: 3.57567e+07
# [92]	valid_0's l1: 4548.27	valid_0's l2: 3.59981e+07
# [93]	valid_0's l1: 4544.94	valid_0's l2: 3.60136e+07
# [94]	valid_0's l1: 4556.76	valid_0's l2: 3.62739e+07
# [95]	valid_0's l1: 4568.4	valid_0's l2: 3.65463e+07
# [96]	valid_0's l1: 4551.53	valid_0's l2: 3.63963e+07
# Early stopping, best iteration is:
# [91]	valid_0's l1: 4536.39	valid_0's l2: 3.57567e+07
# The rmse of prediction is: 5979.69209154

# %%
pd.DataFrame(gbm.predict(df.iloc[:,3:], num_iteration=gbm.best_iteration)).describe()
# Out:
#                   0
# count    240.000000
# mean   59972.139972
# std     6052.999038
# min    51855.132350
# 25%    54092.834771
# 50%    60393.745792
# 75%    65424.912713
# max    69890.955846
