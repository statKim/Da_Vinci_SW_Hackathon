# %%
# coding: utf-8
# pylint: disable = invalid-name, C0111
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

path = "c:/Users/Jiwan/Desktop/Hackathon/"
df = pd.read_csv(path+'buk.csv')

df_train, df_test = train_test_split(df, test_size=0.1, random_state=777)

y_train = df_train.iloc[:,2]
y_test = df_test.iloc[:,2]
X_train = df_train.iloc[:,3:]
X_test = df_test.iloc[:,3:]

# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=2000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)

gbm.save_model('model_buk.txt')

y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# eval
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# [1]	valid_0's l1: 1949.25	valid_0's l2: 5.59924e+06
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's l1: 1923.07	valid_0's l2: 5.51693e+06
# [3]	valid_0's l1: 1866.94	valid_0's l2: 5.27878e+06
# [4]	valid_0's l1: 1848.44	valid_0's l2: 5.17279e+06
# [5]	valid_0's l1: 1797.87	valid_0's l2: 4.95968e+06
# [6]	valid_0's l1: 1775.44	valid_0's l2: 4.85722e+06
# [7]	valid_0's l1: 1731.68	valid_0's l2: 4.68437e+06
# [8]	valid_0's l1: 1689.69	valid_0's l2: 4.52552e+06
# [9]	valid_0's l1: 1654.88	valid_0's l2: 4.37796e+06
# [10]	valid_0's l1: 1624.16	valid_0's l2: 4.24039e+06
# [11]	valid_0's l1: 1585.02	valid_0's l2: 4.08525e+06
# [12]	valid_0's l1: 1547.42	valid_0's l2: 3.94298e+06
# [13]	valid_0's l1: 1511.29	valid_0's l2: 3.81247e+06
# [14]	valid_0's l1: 1476.54	valid_0's l2: 3.69268e+06
# [15]	valid_0's l1: 1461.07	valid_0's l2: 3.63095e+06
# [16]	valid_0's l1: 1438.1	valid_0's l2: 3.5475e+06
# [17]	valid_0's l1: 1423.7	valid_0's l2: 3.47119e+06
# [18]	valid_0's l1: 1411.59	valid_0's l2: 3.41886e+06
# [19]	valid_0's l1: 1401.11	valid_0's l2: 3.35832e+06
# [20]	valid_0's l1: 1387.9	valid_0's l2: 3.29682e+06
# [21]	valid_0's l1: 1366.11	valid_0's l2: 3.23013e+06
# [22]	valid_0's l1: 1352.35	valid_0's l2: 3.18759e+06
# [23]	valid_0's l1: 1345.68	valid_0's l2: 3.13134e+06
# [24]	valid_0's l1: 1339.94	valid_0's l2: 3.10236e+06
# [25]	valid_0's l1: 1339.11	valid_0's l2: 3.08021e+06
# [26]	valid_0's l1: 1340.14	valid_0's l2: 3.04854e+06
# [27]	valid_0's l1: 1342.67	valid_0's l2: 3.02984e+06
# [28]	valid_0's l1: 1345.68	valid_0's l2: 3.01217e+06
# [29]	valid_0's l1: 1353.02	valid_0's l2: 3.01104e+06
# [30]	valid_0's l1: 1351.44	valid_0's l2: 2.99425e+06
# Early stopping, best iteration is:
# [25]	valid_0's l1: 1339.11	valid_0's l2: 3.08021e+06
# The rmse of prediction is: 1755.0529523

# %%
pd.DataFrame(gbm.predict(df.iloc[:,3:], num_iteration=gbm.best_iteration)).describe()
# Out:
#                   0
# count    240.000000
# mean   12053.101583
# std     1384.281826
# min     9429.889203
# 25%    10571.448374
# 50%    12624.342788
# 75%    13075.647515
# max    13787.489299
