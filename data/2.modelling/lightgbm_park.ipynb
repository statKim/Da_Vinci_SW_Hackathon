# %%
# coding: utf-8
# pylint: disable = invalid-name, C0111
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

path = "c:/Users/Jiwan/Desktop/Hackathon/"
df = pd.read_csv(path+'park.csv')

df_train, df_test = train_test_split(df, test_size=0.1, random_state=777)

y_train = df_train.iloc[:,2]
y_test = df_test.iloc[:,2]
X_train = df_train.iloc[:,3:]
X_test = df_test.iloc[:,3:]

# create dataset for lightgbm
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# specify your configurations as a dict
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'l1'},
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}
# train
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=2000,
                valid_sets=lgb_eval,
                early_stopping_rounds=5)

gbm.save_model('model_park.txt')

y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)
# eval
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# [1]	valid_0's l1: 3357.25	valid_0's l2: 1.35234e+07
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's l1: 3325.13	valid_0's l2: 1.32282e+07
# [3]	valid_0's l1: 3293.15	valid_0's l2: 1.29456e+07
# [4]	valid_0's l1: 3261.32	valid_0's l2: 1.26754e+07
# [5]	valid_0's l1: 3235.74	valid_0's l2: 1.24627e+07
# [6]	valid_0's l1: 3237.18	valid_0's l2: 1.25245e+07
# [7]	valid_0's l1: 3209.54	valid_0's l2: 1.22537e+07
# [8]	valid_0's l1: 3182.03	valid_0's l2: 1.19979e+07
# [9]	valid_0's l1: 3140.98	valid_0's l2: 1.16872e+07
# [10]	valid_0's l1: 3113.83	valid_0's l2: 1.14593e+07
# [11]	valid_0's l1: 3075.11	valid_0's l2: 1.12038e+07
# [12]	valid_0's l1: 3038.52	valid_0's l2: 1.09746e+07
# [13]	valid_0's l1: 2993.52	valid_0's l2: 1.06685e+07
# [14]	valid_0's l1: 2957.51	valid_0's l2: 1.04564e+07
# [15]	valid_0's l1: 2924.27	valid_0's l2: 1.02316e+07
# [16]	valid_0's l1: 2884.99	valid_0's l2: 9.9963e+06
# [17]	valid_0's l1: 2860.91	valid_0's l2: 9.86202e+06
# [18]	valid_0's l1: 2822.09	valid_0's l2: 9.64722e+06
# [19]	valid_0's l1: 2820.5	valid_0's l2: 9.68448e+06
# [20]	valid_0's l1: 2782.28	valid_0's l2: 9.48141e+06
# [21]	valid_0's l1: 2755.69	valid_0's l2: 9.35665e+06
# [22]	valid_0's l1: 2726.3	valid_0's l2: 9.21786e+06
# [23]	valid_0's l1: 2723.3	valid_0's l2: 9.2481e+06
# [24]	valid_0's l1: 2694.37	valid_0's l2: 9.11931e+06
# [25]	valid_0's l1: 2658.62	valid_0's l2: 8.94762e+06
# [26]	valid_0's l1: 2630.69	valid_0's l2: 8.82151e+06
# [27]	valid_0's l1: 2625.54	valid_0's l2: 8.79904e+06
# [28]	valid_0's l1: 2597.91	valid_0's l2: 8.68239e+06
# [29]	valid_0's l1: 2601.99	valid_0's l2: 8.72434e+06
# [30]	valid_0's l1: 2570.55	valid_0's l2: 8.60214e+06
# [31]	valid_0's l1: 2553.04	valid_0's l2: 8.58096e+06
# [32]	valid_0's l1: 2544.87	valid_0's l2: 8.54709e+06
# [33]	valid_0's l1: 2509.8	valid_0's l2: 8.42152e+06
# [34]	valid_0's l1: 2496.31	valid_0's l2: 8.29562e+06
# [35]	valid_0's l1: 2461.61	valid_0's l2: 8.1794e+06
# [36]	valid_0's l1: 2431.71	valid_0's l2: 8.07682e+06
# [37]	valid_0's l1: 2403.3	valid_0's l2: 7.98594e+06
# [38]	valid_0's l1: 2376.32	valid_0's l2: 7.90554e+06
# [39]	valid_0's l1: 2371.09	valid_0's l2: 7.91965e+06
# [40]	valid_0's l1: 2341	valid_0's l2: 7.84126e+06
# [41]	valid_0's l1: 2321.22	valid_0's l2: 7.85619e+06
# [42]	valid_0's l1: 2302.46	valid_0's l2: 7.8775e+06
# [43]	valid_0's l1: 2285.99	valid_0's l2: 7.86302e+06
# [44]	valid_0's l1: 2272.86	valid_0's l2: 7.89257e+06
# [45]	valid_0's l1: 2266.75	valid_0's l2: 7.90031e+06
# Early stopping, best iteration is:
# [40]	valid_0's l1: 2341	valid_0's l2: 7.84126e+06
# The rmse of prediction is: 2800.22464733

# %%
pd.DataFrame(gbm.predict(df.iloc[:,3:], num_iteration=gbm.best_iteration)).describe()
# Out:
#                   0
# count    240.000000
# mean   22699.275917
# std     2146.644270
# min    19168.921016
# 25%    20851.026073
# 50%    23378.666006
# 75%    24488.869365
# max    26133.906315
